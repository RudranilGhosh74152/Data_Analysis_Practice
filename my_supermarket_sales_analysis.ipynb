# %% [markdown]
# <a href="https://www.kaggle.com/code/rudranilghosh/my-supermarket-sales-analysis?scriptVersionId=144863664" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
#  Dataset Link - https://www.kaggle.com/datasets/aungpyaeap/supermarket-sales

# %% [markdown]
# Importing libraries to perform analysis.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Transforming the dataset into Pandas dataframe.

# %%
supermarket_sales_data=pd.read_csv('/kaggle/input/supermarket-sales/supermarket_sales - Sheet1.csv')

# %% [markdown]
# Making a copy of the dataframe so that the original dataframe doesn't gets changed after any operation on the dataframe.

# %%
df=supermarket_sales_data.copy()

# %% [markdown]
# Reading few data from the dataframe to get overview.

# %%
df.head(2)

# %% [markdown]
# Displaying the columns of the dataframe.

# %%
df.columns

# %% [markdown]
# # Displaying  5 rows of the Dataset for getting an overview of the data in the dataset.

# %%
df.sample(5)

# %% [markdown]
# # Finding shape of our dataset.

# %%
print('The number of rows are:',df.shape[0])
print('The number of columns are:',df.shape[1])

# %% [markdown]
# # Checking for null values.

# %%
df.isnull().sum()

# %% [markdown]
# No null values in any column.

# %% [markdown]
# # Fetching description about the dataset.

# %%
df.info()

# %% [markdown]
# As I see Date  column is represented as object dtype changing it to datetime dtype.

# %%
df.Date=pd.to_datetime(df.Date)

# %%
df.info()

# %% [markdown]
# # Fetching overall statistics on the dataframe.

# %%
df.describe()

# %% [markdown]
# # Finding aggregate sales among branches.

# %%
df.columns

# %%
df['Branch'].value_counts()

# %%
df['Branch'].value_counts().plot(kind='pie',autopct='%1.2f%%')
plt.xlabel('Branch Name',fontsize=10)
plt.xticks(fontsize=8)

# %% [markdown]
# Branch 'A' has more sales

# %% [markdown]
# # Finding most popular payment methods used by customers.

# %%
df.columns

# %%
df.Payment.value_counts().sort_values(ascending=False)

# %% [markdown]
# Highest Ewallet payments i.e, 345 payments.

# %% [markdown]
# # Payment method distribution.

# %%
df.Payment.value_counts().sort_values(ascending=False).plot(kind='pie',autopct='%1.2f%%',ylabel='')

# %% [markdown]
# Most customers have used Ewallet as their payment method followed by Cash and credit card the least.

# %% [markdown]
# # Finding the customer ratings distribution.

# %%
df.columns

# %%
df.Rating.value_counts().sort_values(ascending=False)

# %%
df.Rating.value_counts().plot(kind='bar',figsize=(10,5),fontsize=8)

# %% [markdown]
# Most of the customers have given a rating of 6 for the products they purchased.

# %% [markdown]
# # Finding average gross income according to cities.

# %%
df.columns

# %%
df.pivot_table(index='City',values='gross income',aggfunc='mean')

# %% [markdown]
# In Naypyitaw city we have higher gross income.

# %%
df.pivot_table(index='City',values='gross income',aggfunc='mean').plot(kind='bar',xlabel='City',ylabel='Gross Income',fontsize=10,figsize=(5,5),color='lightgreen')
plt.xticks(rotation=70 ,fontsize=11)

# %% [markdown]
# # Product catergory with average rating in different branch.

# %%
df.columns

# %%
df.pivot_table(index='Product line',columns='Branch',values='Rating',aggfunc='mean')

# %% [markdown]
# # Finding the most profitable branch as per gross income

# %%
df.columns

# %%
df.pivot_table(index='Branch',values='gross income',aggfunc='sum').sort_values(by ='gross income',ascending=False)

# %%
df.pivot_table(index='Branch',values='gross income',aggfunc='sum').plot(kind='bar',color=['orange'],figsize=(5,4))

# %% [markdown]
# Branch C has highest gross income among thye two other branches.

# %% [markdown]
# # Which gender buys more?

# %%
df.columns

# %%
df.pivot_table(index='Gender',columns='City',values='Total')

# %% [markdown]
# As we can see in each city on an average Females shop more than Males

# %% [markdown]
# # Finding which product line has maximum gross income.

# %%
df.columns

# %%
df.pivot_table(index='Product line',values='gross income',aggfunc='median').sort_values(by='gross income',ascending =False)

# %%
df.pivot_table(index='Product line',values='gross income',aggfunc='median').plot()
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# After visualizing we can conclude Home and lifestyle product line has highest average gross income among others.

# %% [markdown]
# # Finding mode of payment according to cities.

# %%
pd.crosstab(df['City'],df['Payment'])

# %%
pd.crosstab(df['City'],df['Payment']).plot(kind='bar',figsize=(13,5))
plt.xticks(rotation=70,fontsize=10)
plt.show()

# %% [markdown]
# *  Mandalay -> Most of the customers used Ewallet.
# *  Naypyitaw -> Most of the customers used cash.
# *  Yangon -> Most of the customers used Ewallet

# %% [markdown]
# # Finding Tax values according to product categories.

# %%
df.pivot_table(index='Product line',values='Tax 5%',aggfunc='mean').sort_values(by='Tax 5%',ascending =False)

# %%
df.pivot_table(index='Product line',values='Tax 5%',aggfunc='mean').plot(kind='line',color='purple')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# As we can visualize from the above chart on an average products of Home and Lifestyle has highest tax average and Fashion accessories has lowest tax average on its products.

# %%
df.pivot_table(index='Product line',values='Tax 5%',aggfunc='max').sort_values(by='Tax 5%',ascending =False)

# %%
df.pivot_table(index='Product line',values='Tax 5%',aggfunc='max').plot(kind='line',color='orange')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# As we can see from the line chart Fashion accessories has the maximum tax on products.
